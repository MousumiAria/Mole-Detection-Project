# %%
import numpy as np
import pandas as pd

# %%
#Create A Datafream
df_metadata= pd.read_csv('/home/becode/BeCode Projects/Mole-Detection-Project/archive/HAM10000_metadata.csv', sep=',')
df_metadata.head(10)
# Out:
#      lesion_id      image_id   dx dx_type   age     sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0    male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0    male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0    male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0    male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0    male          ear
# 5  HAM_0001466  ISIC_0027850  bkl   histo  75.0    male          ear
# 6  HAM_0002761  ISIC_0029176  bkl   histo  60.0    male         face
# 7  HAM_0002761  ISIC_0029068  bkl   histo  60.0    male         face
# 8  HAM_0005132  ISIC_0025837  bkl   histo  70.0  female         back
# 9  HAM_0005132  ISIC_0025209  bkl   histo  70.0  female         back

# %%
#Checking rows/Avelable rows & columns
df_metadata.shape
# Out:
# (10015, 7)

# %%
# Check Duplicates
df_metadata.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10010    False
# 10011    False
# 10012    False
# 10013    False
# 10014    False
# Length: 10015, dtype: bool

# %%
#Count all NaN in a DataFrame (both columns & Rows)
df_metadata.isnull().sum().sum()
# Out:
# 57

# %%
# Drop all NaN
df_metadata=df_metadata.dropna()

# %%
# Chack again metadata file
df_metadata.shape
# Out:
# (9958, 7)

# %%
df_8_8_L= pd.read_csv('/home/becode/BeCode Projects/Mole-Detection-Project/archive/hmnist_8_8_L.csv', sep=',')
df_8_8_L.head(10)
# Out:
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        172        182        191        183        180        181
# 1         98        149        170        193        183        162
# 2        165        164        179        172        152        163
# 3        109        159        167        166        163        159
# 4        173        202        210        194        208        248
# 5         17        155        229        233        234        205
# 6        168        170        169        178        177        174
# 7        141        153        162        171        174        171
# 8        138        157        177        182        181        174
# 9        181        173        191        197        198        181
#
#    pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel0055  pixel0056  \
# 0        165        164        173        192  ...        159        171
# ...

# %%
df_8_8_RGB= pd.read_csv('/home/becode/BeCode Projects/Mole-Detection-Project/archive/hmnist_8_8_RGB.csv', sep=',')
df_28_28_L= pd.read_csv('/home/becode/BeCode Projects/Mole-Detection-Project/archive/hmnist_28_28_L.csv', sep=',')
df_28_28_RGB= pd.read_csv('/home/becode/BeCode Projects/Mole-Detection-Project/archive/hmnist_28_28_RGB.csv', sep=',')
